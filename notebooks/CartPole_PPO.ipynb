# %% [markdown]
# # My implementation of PPO Algorithm

# %% [markdown]
# ## import some packages and check the env

# %%
import gymnasium as gym
import numpy as np
# these are new packages in this file
import panda_gym
import stable_baselines3
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.env_util import make_vec_env
from collections import deque
import matplotlib.pyplot as plt
import random
import imageio

import tensorboard
from torch.utils.tensorboard import SummaryWriter
# %matplotlib inline

# %%
env_id = 'CartPole-v1'
env = gym.make(env_id)
state_space = env.observation_space
action_space = env.action_space.shape
print(f'state space: {state_space}')
print(f'action space: {action_space}')
# Out:
# state space: Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)
# action space: ()

# %% [markdown]
# ## Build networks of PPO
#
# The networks are same with A2C

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
# we don't use the Categorical since the actions are continuous
# we should use the Normal to model the continous distribution
from torch.distributions import Categorical,Normal

# %%
writer = SummaryWriter()

# %%
# helper function: to concatenate the input and convert them to tensor
def t(x):
    if isinstance(x, np.ndarray):
            x = torch.tensor(x, dtype=torch.float)
    return x

# %%
class Actor(nn.Module):
    def __init__(self, state_space, action_space,lr,device):
        super(Actor,self).__init__()
        self.model = nn.Sequential(
            nn.Linear(state_space, 64),
            nn.Tanh(),
            nn.Linear(64, 32),
            nn.Tanh(),
            nn.Linear(32, action_space), #the acition space is continous
            nn.Softmax()
        )
        self.optimizer = optim.Adam(self.parameters(),lr=lr)
        self.to(device)
    
    def forward(self, X):
        return self.model(t(X))

# %%
class Critic(nn.Module):
    def __init__(self, state_space,lr,device):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(state_space, 64),
            nn.ReLU(),
            nn.Linear(64,32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )
        self.optimizer = optim.Adam(self.parameters(),lr=lr)
        self.to(device)
    
    def forward(self, X):
        return self.model(t(X))

# %% [markdown]
# ![clip](Algotithms/clipped.jpg)

# %%
class Agent():
    def __init__(
        self,
        env: gym.envs,
        state_space: int,
        action_space: int,
        lr: float,
        device: torch.device,
        gamma: float, # discounted rewards
        # gae_lambda: float,
        # policy_clip: float,
        # batch_size: int,
        timesteps_per_batch: int,
        n_updates_per_iteration: int,
        clip: float,
        n_training_episodes: int,
        n_eval_episodes: int,
        max_t: int 
    ):
         # init the variables
        self.env = env
        self.state_space = state_space
        self.action_space = action_space
        self.lr = lr
        self.device = device
        self.gamma = gamma
        # self.gae_lambda = gae_lambda
        # self.policy_clip = policy_clip
        # self.batch_size = batch_size
        self.timesteps_per_batch = timesteps_per_batch
        self.n_updates_per_iteration = n_updates_per_iteration
        self.clip = clip
        self.n_training_episodes = n_training_episodes
        self.n_eval_episodes = n_eval_episodes
        self.max_t = max_t
        
        # self.actor_critic = ActorCritic(state_space,action_space,
        #                                 lr,device)
        self.actor = Actor(state_space,action_space,lr,device)
        self.critic = Critic(state_space,lr,device)
   

        
    def act(self,state):
        probs = self.actor(state)
        dist = Categorical(probs.cpu())
        action = dist.sample()
        log_prob = dist.log_prob(action)
        # entropy = dist.entropy()
        return action.item(),log_prob
    
    def step(self,action):
        # the agent take the action and obtain the next observation and immedient reward
        # Then, push the infos into the buffer
        next_obs,reward,terminated,truncated,info = self.env.step(action)
        done = terminated or truncated
        return next_obs, reward, done
    
    # this is new in PPO
    def rollout(self):
        
        # batch_data
        batch_obs = []             # batch observations
        batch_acts = []            # batch actions
        batch_log_probs = []       # log probs of each action
        batch_rews = []            # batch rewards
        batch_rtgs = []            # batch rewards-to-go
        batch_lens = []            # episodic lengths in batch

        t = 0
        global step
        step = 0
        while t < self.timesteps_per_batch:
            ep_rews = []
            state,info = self.env.reset()
            done = False
            
            for ep_t in range(self.max_t):
                t += 1
                batch_obs.append(state)
                action,log_prob = self.act(state)
                state_,reward,done = self.step(action)
                ep_rews.append(reward)
                batch_acts.append(action)
                batch_log_probs.append(log_prob)
                
                if done:
                    break
                
                state = state_
                
            batch_lens.append(ep_t + 1)
            writer.add_scalar('ep_len',ep_t+1,step)
            batch_rews.append(ep_rews)
            writer.add_scalar('ep_avg_reward',np.mean(ep_rews),step)
            step += 1
            
        # Reshape data as tensors in the shape specified before returning
        batch_obs = torch.tensor(batch_obs, dtype=torch.float)
        batch_acts = torch.tensor(batch_acts, dtype=torch.float)
        batch_log_probs = torch.tensor(batch_log_probs, dtype=torch.float)
        
        # compute the reward to go
        for ep_rews in reversed(batch_rews):
            
            discounted_reward = 0
            for rew in reversed(ep_rews):
                discounted_reward = rew + discounted_reward * self.gamma
                batch_rtgs.insert(0,discounted_reward)
        
        batch_rtgs = torch.tensor(batch_rtgs,dtype=torch.float)
        return batch_obs, batch_acts, batch_log_probs, batch_rtgs, batch_lens

    
    
    
    
    
    def update(self):
        # compute the value,advantages and update the network
        batch_obs, batch_acts, batch_log_probs, batch_rtgs, batch_lens = self.rollout()
        ## compute the value
        V = self.critic(batch_obs)
        advantage = batch_rtgs - V.detach()
        # normalize advantage
        advantage = (advantage - advantage.mean()) / (advantage.std() + 1e-10)
        
        # compute the loss
        ## current V and action
        for _ in range(self.n_updates_per_iteration):
            logits = self.actor(batch_obs)
            dist = Categorical(logits)
            curr_log_probs = dist.log_prob(batch_acts)
            ## compute ratio
            ratios = torch.exp(curr_log_probs - batch_log_probs)
            ## compute surrogate loss
            surr1 = ratios * advantage
            surr2 = torch.clamp(ratios, 1 - self.clip, 1 + self.clip) * advantage
            
            # actor loss
            actor_loss = (-torch.min(surr1,surr2)).mean()
            self.actor.optimizer.zero_grad()
            actor_loss.backward(retain_graph=True)
            self.actor.optimizer.step()
            
            # critic loss
            V = self.critic(batch_obs)
            loss = nn.MSELoss()
            critic_loss = loss(V,batch_rtgs)
            self.critic.optimizer.zero_grad()
            critic_loss.backward()
            self.critic.optimizer.step()
            writer.add_scalar('policy loss',actor_loss)
            writer.add_scalar('critic loss',critic_loss)
            
            
        
        
    def train(self):
        for episode in range(self.n_training_episodes):
            self.update()
            if episode % 100 == 0:
                print(f'running {episode}')

# %%
# Hyperparameter
state_space = env.observation_space.shape[0]
action_space = env.action_space.n
lr = 0.005
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
gamma = 0.95
clip = 0.2
timesteps_per_batch = 4800
n_updates_per_iteration = 5
n_training_episodes = 1000
n_eval_episodes = 100
max_t = 1600

CartPoleAgent = Agent(
    env,
    state_space,
    action_space,
    lr,
    device,
    gamma,
    timesteps_per_batch,
    n_updates_per_iteration,
    clip,
    n_training_episodes,
    n_eval_episodes,
    max_t
)

# %%
CartPoleAgent.train()
# Out:
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/container.py:217: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# /var/folders/xt/fs8f0mrx5c7d2_ny5vdyy0ym0000gp/T/ipykernel_78359/383444071.py:99: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:248.)
#   batch_obs = torch.tensor(batch_obs, dtype=torch.float)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4801])) that is different to the input size (torch.Size([4801, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# running 0
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4809])) that is different to the input size (torch.Size([4809, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4810])) that is different to the input size (torch.Size([4810, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4822])) that is different to the input size (torch.Size([4822, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4949])) that is different to the input size (torch.Size([4949, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4883])) that is different to the input size (torch.Size([4883, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4875])) that is different to the input size (torch.Size([4875, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5056])) that is different to the input size (torch.Size([5056, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4907])) that is different to the input size (torch.Size([4907, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4853])) that is different to the input size (torch.Size([4853, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4826])) that is different to the input size (torch.Size([4826, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4962])) that is different to the input size (torch.Size([4962, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4824])) that is different to the input size (torch.Size([4824, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4884])) that is different to the input size (torch.Size([4884, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4869])) that is different to the input size (torch.Size([4869, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4852])) that is different to the input size (torch.Size([4852, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5029])) that is different to the input size (torch.Size([5029, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4803])) that is different to the input size (torch.Size([4803, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4958])) that is different to the input size (torch.Size([4958, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4953])) that is different to the input size (torch.Size([4953, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4944])) that is different to the input size (torch.Size([4944, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5205])) that is different to the input size (torch.Size([5205, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4997])) that is different to the input size (torch.Size([4997, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5139])) that is different to the input size (torch.Size([5139, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5189])) that is different to the input size (torch.Size([5189, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4955])) that is different to the input size (torch.Size([4955, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4808])) that is different to the input size (torch.Size([4808, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4820])) that is different to the input size (torch.Size([4820, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5256])) that is different to the input size (torch.Size([5256, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4970])) that is different to the input size (torch.Size([4970, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4987])) that is different to the input size (torch.Size([4987, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4988])) that is different to the input size (torch.Size([4988, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5092])) that is different to the input size (torch.Size([5092, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4806])) that is different to the input size (torch.Size([4806, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5136])) that is different to the input size (torch.Size([5136, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5000])) that is different to the input size (torch.Size([5000, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5201])) that is different to the input size (torch.Size([5201, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5050])) that is different to the input size (torch.Size([5050, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5058])) that is different to the input size (torch.Size([5058, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4904])) that is different to the input size (torch.Size([4904, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4996])) that is different to the input size (torch.Size([4996, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4899])) that is different to the input size (torch.Size([4899, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5149])) that is different to the input size (torch.Size([5149, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5271])) that is different to the input size (torch.Size([5271, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5204])) that is different to the input size (torch.Size([5204, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# running 100
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4901])) that is different to the input size (torch.Size([4901, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4911])) that is different to the input size (torch.Size([4911, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4999])) that is different to the input size (torch.Size([4999, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4855])) that is different to the input size (torch.Size([4855, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4914])) that is different to the input size (torch.Size([4914, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5043])) that is different to the input size (torch.Size([5043, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5293])) that is different to the input size (torch.Size([5293, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5230])) that is different to the input size (torch.Size([5230, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5120])) that is different to the input size (torch.Size([5120, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4835])) that is different to the input size (torch.Size([4835, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5026])) that is different to the input size (torch.Size([5026, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4945])) that is different to the input size (torch.Size([4945, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4928])) that is different to the input size (torch.Size([4928, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5001])) that is different to the input size (torch.Size([5001, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5178])) that is different to the input size (torch.Size([5178, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4865])) that is different to the input size (torch.Size([4865, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5223])) that is different to the input size (torch.Size([5223, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4856])) that is different to the input size (torch.Size([4856, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4837])) that is different to the input size (torch.Size([4837, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4812])) that is different to the input size (torch.Size([4812, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4819])) that is different to the input size (torch.Size([4819, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5015])) that is different to the input size (torch.Size([5015, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4860])) that is different to the input size (torch.Size([4860, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5180])) that is different to the input size (torch.Size([5180, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5150])) that is different to the input size (torch.Size([5150, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4864])) that is different to the input size (torch.Size([4864, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5054])) that is different to the input size (torch.Size([5054, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5024])) that is different to the input size (torch.Size([5024, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4975])) that is different to the input size (torch.Size([4975, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4921])) that is different to the input size (torch.Size([4921, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4881])) that is different to the input size (torch.Size([4881, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4986])) that is different to the input size (torch.Size([4986, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4948])) that is different to the input size (torch.Size([4948, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5244])) that is different to the input size (torch.Size([5244, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5278])) that is different to the input size (torch.Size([5278, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4857])) that is different to the input size (torch.Size([4857, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4897])) that is different to the input size (torch.Size([4897, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4926])) that is different to the input size (torch.Size([4926, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4925])) that is different to the input size (torch.Size([4925, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5035])) that is different to the input size (torch.Size([5035, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4968])) that is different to the input size (torch.Size([4968, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5291])) that is different to the input size (torch.Size([5291, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# running 200
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4891])) that is different to the input size (torch.Size([4891, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5168])) that is different to the input size (torch.Size([5168, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5022])) that is different to the input size (torch.Size([5022, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5209])) that is different to the input size (torch.Size([5209, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5091])) that is different to the input size (torch.Size([5091, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4847])) that is different to the input size (torch.Size([4847, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4912])) that is different to the input size (torch.Size([4912, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5064])) that is different to the input size (torch.Size([5064, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4840])) that is different to the input size (torch.Size([4840, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5153])) that is different to the input size (torch.Size([5153, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5080])) that is different to the input size (torch.Size([5080, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5042])) that is different to the input size (torch.Size([5042, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5266])) that is different to the input size (torch.Size([5266, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5012])) that is different to the input size (torch.Size([5012, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4849])) that is different to the input size (torch.Size([4849, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5226])) that is different to the input size (torch.Size([5226, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5027])) that is different to the input size (torch.Size([5027, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4893])) that is different to the input size (torch.Size([4893, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5047])) that is different to the input size (torch.Size([5047, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4882])) that is different to the input size (torch.Size([4882, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4830])) that is different to the input size (torch.Size([4830, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5009])) that is different to the input size (torch.Size([5009, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4976])) that is different to the input size (torch.Size([4976, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5251])) that is different to the input size (torch.Size([5251, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4909])) that is different to the input size (torch.Size([4909, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5111])) that is different to the input size (torch.Size([5111, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4916])) that is different to the input size (torch.Size([4916, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4930])) that is different to the input size (torch.Size([4930, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4924])) that is different to the input size (torch.Size([4924, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5106])) that is different to the input size (torch.Size([5106, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4880])) that is different to the input size (torch.Size([4880, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5160])) that is different to the input size (torch.Size([5160, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5036])) that is different to the input size (torch.Size([5036, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4966])) that is different to the input size (torch.Size([4966, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4938])) that is different to the input size (torch.Size([4938, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5065])) that is different to the input size (torch.Size([5065, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ...
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5219])) that is different to the input size (torch.Size([5219, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5283])) that is different to the input size (torch.Size([5283, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4973])) that is different to the input size (torch.Size([4973, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5169])) that is different to the input size (torch.Size([5169, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5270])) that is different to the input size (torch.Size([5270, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4964])) that is different to the input size (torch.Size([4964, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4845])) that is different to the input size (torch.Size([4845, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5070])) that is different to the input size (torch.Size([5070, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# running 700
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5193])) that is different to the input size (torch.Size([5193, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5187])) that is different to the input size (torch.Size([5187, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4887])) that is different to the input size (torch.Size([4887, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5280])) that is different to the input size (torch.Size([5280, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5108])) that is different to the input size (torch.Size([5108, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5200])) that is different to the input size (torch.Size([5200, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5272])) that is different to the input size (torch.Size([5272, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4923])) that is different to the input size (torch.Size([4923, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4833])) that is different to the input size (torch.Size([4833, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5275])) that is different to the input size (torch.Size([5275, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4935])) that is different to the input size (torch.Size([4935, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5159])) that is different to the input size (torch.Size([5159, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4841])) that is different to the input size (torch.Size([4841, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5083])) that is different to the input size (torch.Size([5083, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4842])) that is different to the input size (torch.Size([4842, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5006])) that is different to the input size (torch.Size([5006, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5192])) that is different to the input size (torch.Size([5192, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5141])) that is different to the input size (torch.Size([5141, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4985])) that is different to the input size (torch.Size([4985, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4941])) that is different to the input size (torch.Size([4941, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5214])) that is different to the input size (torch.Size([5214, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5099])) that is different to the input size (torch.Size([5099, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5176])) that is different to the input size (torch.Size([5176, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5274])) that is different to the input size (torch.Size([5274, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# running 800
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5258])) that is different to the input size (torch.Size([5258, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4844])) that is different to the input size (torch.Size([4844, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4870])) that is different to the input size (torch.Size([4870, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4920])) that is different to the input size (torch.Size([4920, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# running 900
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4994])) that is different to the input size (torch.Size([4994, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4971])) that is different to the input size (torch.Size([4971, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5277])) that is different to the input size (torch.Size([5277, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([5231])) that is different to the input size (torch.Size([5231, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([4993])) that is different to the input size (torch.Size([4993, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %%
# !tensorboard --logdir=runs
# Out:
# TensorFlow installation not found - running with reduced feature set.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.14.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C
