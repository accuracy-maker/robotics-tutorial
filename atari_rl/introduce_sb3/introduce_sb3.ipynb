# %% [markdown]
# # This file aims to introduce the library SB3, and how to use it

# %% [markdown]
# ## Basic Usage: Training, Saving, Loading

# %%
import gymnasium as gym

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy


# Create environment
env = gym.make("LunarLander-v2", render_mode="rgb_array")

# Instantiate the agent
model = DQN("MlpPolicy", env, verbose=1)
# Train the agent and display a progress bar
model.learn(total_timesteps=int(2e5), progress_bar=True)
# Save the agent
model.save("dqn_lunar")
del model  # delete trained model to demonstrate loading

# Load the trained agent
# NOTE: if you have loading issue, you can pass `print_system_info=True`
# to compare the system on which the model was trained vs the current one
# model = DQN.load("dqn_lunar", env=env, print_system_info=True)
model = DQN.load("dqn_lunar", env=env)

# Evaluate the agent
# NOTE: If you use wrappers with your environment that modify rewards,
#       this will be reflected here. To evaluate with original rewards,
#       wrap environment in a "Monitor" wrapper before other wrappers.
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)

# Enjoy trained agent
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Output()
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.8     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2233     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 351      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -240     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3197     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 751      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95       |
# |    ep_rew_mean      | -223     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 3808     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | -220     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4286     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -235     |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4530     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1881     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 131      |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2756     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | -218     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2943     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3539     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -212     |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3059     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3821     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -207     |
# |    exploration_rate | 0.798    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3209     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4247     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -207     |
# |    exploration_rate | 0.778    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3300     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.759    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 3414     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5067     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 3448     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.728    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 3536     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5717     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.708    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 3648     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6153     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.685    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 3759     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6623     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 3846     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6962     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.652    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 3916     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7320     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4051     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8026     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4117     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 8341     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.587    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4175     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 8699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4238     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9048     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4291     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9424     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.533    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 4348     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9834     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.516    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4367     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10188    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.498    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4418     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10569    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.484    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4464     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10860    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.47     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4501     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.451    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 4550     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11561    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 4588     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.416    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4632     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12302    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4652     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12622    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.383    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4691     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.364    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 4727     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.347    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 4765     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13738    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 4794     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 14076    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.313    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 4828     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 14468    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.299    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 4850     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 14749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.282    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 4886     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89       |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.263    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 4917     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.248    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 4943     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15834    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.6     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.231    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 4967     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16181    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.213    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 5001     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16576    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.193    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 5028     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16995    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.176    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 5054     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.159    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 5075     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.143    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 5100     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18035    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.6     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.127    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 5119     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.109    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 5147     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.0928   |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 5162     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.0727   |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 5185     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.0582   |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 5203     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19827    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 5221     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 20140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 5238     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 20515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 5257     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 20835    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.4     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 5271     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 21141    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 5288     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 21425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.7     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 5302     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 21763    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.8     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 5318     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 22062    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.9     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 5328     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 22430    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87       |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 5348     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 22774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.2     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 5366     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 23088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87       |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 5378     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 23447    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.6     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 5391     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 23869    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87       |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 5409     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 24221    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.5     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 5421     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 24582    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.6     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 5435     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 24941    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.9     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 5449     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 25265    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86       |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 5463     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 25600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.7     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 5477     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 26017    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.6     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 5492     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 26371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.6     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 5502     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 26794    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 5513     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 27184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.4     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 5516     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 27502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.4     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 5529     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 27839    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.2     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 5538     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 28144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.1     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 5553     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 28539    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.5     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 5563     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 28891    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.7     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 5577     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 29285    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 5588     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 29719    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.6     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 5599     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 29998    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 5606     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 30331    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 5618     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 30643    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 5626     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 31076    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 5638     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 31402    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 5646     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 31745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 5653     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 32027    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.6     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 5656     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 32411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 5667     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 32761    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 5673     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 33108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89       |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 5686     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 33482    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 5692     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 33909    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 5703     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 34304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 5710     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 34626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 5719     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 34959    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 5724     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 35278    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.6     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 5736     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 35655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.4     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 5743     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 36024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89       |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 5751     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 36397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 5758     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 36770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 5761     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 37142    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 5767     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 37504    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 5774     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 37837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.6     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 5778     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 38144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.4     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 5787     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 38459    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.2     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 5791     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 38813    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 5799     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 39209    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 5802     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 39665    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 5807     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 40046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 5815     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 40375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 5818     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 40776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 5827     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 41143    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 5831     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 41528    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 5835     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 41900    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 5840     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 42297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 5846     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 42612    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 5849     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 42939    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 5856     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 43359    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 5858     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 43769    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 5860     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 44220    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 5866     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 44551    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 5869     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 44925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 5876     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 45261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 5879     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 45633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 5884     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 45957    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -192     |
# ...
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 1163     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 91881    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.654    |
# |    n_updates        | 10470    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 463      |
# |    ep_rew_mean      | -270     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 1135     |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 94519    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.57     |
# |    n_updates        | 11129    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 480      |
# |    ep_rew_mean      | -269     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 1122     |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 96685    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18     |
# |    n_updates        | 11671    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 488      |
# |    ep_rew_mean      | -265     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 1121     |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 97873    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.59     |
# |    n_updates        | 11968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 504      |
# |    ep_rew_mean      | -264     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 1114     |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 99731    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.712    |
# |    n_updates        | 12432    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 528      |
# |    ep_rew_mean      | -259     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 1084     |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 102536   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.992    |
# |    n_updates        | 13133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 564      |
# |    ep_rew_mean      | -249     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 1050     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 106536   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.542    |
# |    n_updates        | 14133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 595      |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 1020     |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 110105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.964    |
# |    n_updates        | 15026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 630      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 980      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 114105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.723    |
# |    n_updates        | 16026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 665      |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 949      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 118105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13     |
# |    n_updates        | 17026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 700      |
# |    ep_rew_mean      | -147     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 922      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 122105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.423    |
# |    n_updates        | 18026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 664      |
# |    fps              | 892      |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 126105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.344    |
# |    n_updates        | 19026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 753      |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 668      |
# |    fps              | 875      |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 130105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.814    |
# |    n_updates        | 20026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 761      |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 672      |
# |    fps              | 856      |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 134105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21     |
# |    n_updates        | 21026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 783      |
# |    ep_rew_mean      | -127     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 676      |
# |    fps              | 836      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 138105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.742    |
# |    n_updates        | 22026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 796      |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 826      |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 142105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.64     |
# |    n_updates        | 23026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 802      |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 684      |
# |    fps              | 811      |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 146105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.42     |
# |    n_updates        | 24026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 822      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 799      |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 150105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.655    |
# |    n_updates        | 25026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 822      |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 782      |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 154105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.903    |
# |    n_updates        | 26026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 830      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 771      |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 158105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.77     |
# |    n_updates        | 27026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 830      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 761      |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 162105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.64     |
# |    n_updates        | 28026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 847      |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 750      |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 166105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.573    |
# |    n_updates        | 29026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 855      |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 743      |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 170105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.8      |
# |    n_updates        | 30026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 871      |
# |    ep_rew_mean      | -125     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 738      |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 174105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.336    |
# |    n_updates        | 31026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 871      |
# |    ep_rew_mean      | -125     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 733      |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 178105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.507    |
# |    n_updates        | 32026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 902      |
# |    ep_rew_mean      | -122     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 725      |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 182105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.97     |
# |    n_updates        | 33026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 916      |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 720      |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 186094   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.474    |
# |    n_updates        | 34023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 929      |
# |    ep_rew_mean      | -114     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 717      |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 189597   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.482    |
# |    n_updates        | 34899    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 953      |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 709      |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 193163   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.221    |
# |    n_updates        | 35790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 974      |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 703      |
# |    time_elapsed     | 280      |
# |    total_timesteps  | 197163   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.413    |
# |    n_updates        | 36790    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ## Multiprocessing: Unleashing the Power of Vectorized Environments

# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.utils import set_random_seed

def make_env(env_id: str, rank: int, seed: int = 0):
    """
    Utility function for multiprocessed env.

    :param env_id: the environment ID
    :param num_env: the number of environments you wish to have in subprocesses
    :param seed: the inital seed for RNG
    :param rank: index of the subprocess
    """
    def _init():
        env = gym.make(env_id, render_mode="human")
        env.reset(seed=seed + rank)
        return env
    set_random_seed(seed)
    return _init

if __name__ == "__main__":
    env_id = "CartPole-v1"
    num_cpu = 4  # Number of processes to use
    # Create the vectorized environment
    vec_env = SubprocVecEnv([make_env(env_id, i) for i in range(num_cpu)])

    # Stable Baselines provides you with make_vec_env() helper
    # which does exactly the previous steps for you.
    # You can choose between `DummyVecEnv` (usually faster) and `SubprocVecEnv`
    # env = make_vec_env(env_id, n_envs=num_cpu, seed=0, vec_env_cls=SubprocVecEnv)

    model = PPO("MlpPolicy", vec_env, verbose=1)
    model.learn(total_timesteps=25_000)

    obs = vec_env.reset()
    for _ in range(1000):
        action, _states = model.predict(obs)
        obs, rewards, dones, info = vec_env.step(action)
        vec_env.render()
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# /Users/gaohaitao/robotics-tutorial/atari_rl/introduce_sb3.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/Users/gaohaitao/robotics-tutorial/atari_rl/introduce_sb3.ipynb#W5sZmlsZQ%3D%3D?line=25'>26</a> num_cpu = 4  # Number of processes to use
#      <a href='vscode-notebook-cell:/Users/gaohaitao/robotics-tutorial/atari_rl/introduce_sb3.ipynb#W5sZmlsZQ%3D%3D?line=26'>27</a> # Create the vectorized environment
# ---> <a href='vscode-notebook-cell:/Users/gaohaitao/robotics-tutorial/atari_rl/introduce_sb3.ipynb#W5sZmlsZQ%3D%3D?line=27'>28</a> vec_env = SubprocVecEnv([make_env(env_id, i) for i in range(num_cpu)])
#      <a href='vscode-notebook-cell:/Users/gaohaitao/robotics-tutorial/atari_rl/introduce_sb3.ipynb#W5sZmlsZQ%3D%3D?line=29'>30</a> # Stable Baselines provides you with make_vec_env() helper
#      <a href='vscode-notebook-cell:/Users/gaohaitao/robotics-tutorial/atari_rl/introduce_sb3.ipynb#W5sZmlsZQ%3D%3D?line=30'>31</a> # which does exactly the previous steps for you.
#      <a href='vscode-notebook-cell:/Users/gaohaitao/robotics-tutorial/atari_rl/introduce_sb3.ipynb#W5sZmlsZQ%3D%3D?line=31'>32</a> # You can choose between `DummyVecEnv` (usually faster) and `SubprocVecEnv`
#      <a href='vscode-notebook-cell:/Users/gaohaitao/robotics-tutorial/atari_rl/introduce_sb3.ipynb#W5sZmlsZQ%3D%3D?line=32'>33</a> # env = make_vec_env(env_id, n_envs=num_cpu, seed=0, vec_env_cls=SubprocVecEnv)
#      <a href='vscode-notebook-cell:/Users/gaohaitao/robotics-tutorial/atari_rl/introduce_sb3.ipynb#W5sZmlsZQ%3D%3D?line=34'>35</a> model = PPO("MlpPolicy", vec_env, verbose=1)
#
# File ~/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py:120, in SubprocVecEnv.__init__(self, env_fns, start_method)
#     117     work_remote.close()
#     119 self.remotes[0].send(("get_spaces", None))
# --> 120 observation_space, action_space = self.remotes[0].recv()
#     122 super().__init__(len(env_fns), observation_space, action_space)
#
# File ~/opt/anaconda3/envs/robotics/lib/python3.10/multiprocessing/connection.py:250, in _ConnectionBase.recv(self)
#     248 self._check_closed()
#     249 self._check_readable()
# --> 250 buf = self._recv_bytes()
#     251 return _ForkingPickler.loads(buf.getbuffer())
#
# File ~/opt/anaconda3/envs/robotics/lib/python3.10/multiprocessing/connection.py:414, in Connection._recv_bytes(self, maxsize)
#     413 def _recv_bytes(self, maxsize=None):
# --> 414     buf = self._recv(4)
#     415     size, = struct.unpack("!i", buf.getvalue())
#     416     if size == -1:
#
# File ~/opt/anaconda3/envs/robotics/lib/python3.10/multiprocessing/connection.py:383, in Connection._recv(self, size, read)
#     381 if n == 0:
#     382     if remaining == size:
# --> 383         raise EOFError
#     384     else:
#     385         raise OSError("got end of file during message")
#
# EOFError:

# %% [markdown]
# It seems that mac cannot use the multiprocess
#
# I successfully run the code in Colab, so you just copy this to Colab notebook

# %% [markdown]
# ## Multiprocessing with off-policy algorithms

# %%
import gymnasium as gym

from stable_baselines3 import SAC
from stable_baselines3.common.env_util import make_vec_env

vec_env = make_vec_env("Pendulum-v1", n_envs=4, seed=0)

# We collect 4 transitions per call to `ènv.step()`
# and performs 2 gradient steps per call to `ènv.step()`
# if gradient_steps=-1, then we would do 4 gradients steps per call to `ènv.step()`
model = SAC("MlpPolicy", vec_env, train_freq=1, gradient_steps=2, verbose=1)
model.learn(total_timesteps=10_000)
# Out:
# Using cpu device
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 113       |
# |    time_elapsed    | 7         |
# |    total_timesteps | 800       |
# | train/             |           |
# |    actor_loss      | 12.2      |
# |    critic_loss     | 0.423     |
# |    ent_coef        | 0.901     |
# |    ent_coef_loss   | -0.173    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 348       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.41e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 108       |
# |    time_elapsed    | 14        |
# |    total_timesteps | 1600      |
# | train/             |           |
# |    actor_loss      | 22.3      |
# |    critic_loss     | 0.224     |
# |    ent_coef        | 0.801     |
# |    ent_coef_loss   | -0.358    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 748       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.48e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 107       |
# |    time_elapsed    | 22        |
# |    total_timesteps | 2400      |
# | train/             |           |
# |    actor_loss      | 35.5      |
# |    critic_loss     | 0.208     |
# |    ent_coef        | 0.714     |
# |    ent_coef_loss   | -0.506    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1148      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.45e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 106       |
# |    time_elapsed    | 30        |
# |    total_timesteps | 3200      |
# | train/             |           |
# |    actor_loss      | 48.7      |
# |    critic_loss     | 0.194     |
# |    ent_coef        | 0.639     |
# |    ent_coef_loss   | -0.637    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1548      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.38e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 106       |
# |    time_elapsed    | 37        |
# |    total_timesteps | 4000      |
# | train/             |           |
# |    actor_loss      | 57.9      |
# |    critic_loss     | 0.258     |
# |    ent_coef        | 0.576     |
# |    ent_coef_loss   | -0.658    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1948      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 106       |
# |    time_elapsed    | 45        |
# |    total_timesteps | 4800      |
# | train/             |           |
# |    actor_loss      | 65.3      |
# |    critic_loss     | 0.427     |
# |    ent_coef        | 0.526     |
# |    ent_coef_loss   | -0.61     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2348      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -1.2e+03 |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 105      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | 68.3     |
# |    critic_loss     | 0.255    |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | -0.551   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2748     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.08e+03 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 104       |
# |    time_elapsed    | 61        |
# |    total_timesteps | 6400      |
# | train/             |           |
# |    actor_loss      | 71.8      |
# |    critic_loss     | 0.361     |
# |    ent_coef        | 0.451     |
# |    ent_coef_loss   | -0.534    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3148      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -994     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 104      |
# |    time_elapsed    | 69       |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | 70.8     |
# |    critic_loss     | 0.431    |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | -0.436   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3548     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -913     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 103      |
# |    time_elapsed    | 77       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 75.3     |
# |    critic_loss     | 0.671    |
# |    ent_coef        | 0.387    |
# |    ent_coef_loss   | -0.452   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3948     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -852     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 103      |
# |    time_elapsed    | 84       |
# |    total_timesteps | 8800     |
# | train/             |          |
# |    actor_loss      | 68.9     |
# |    critic_loss     | 0.822    |
# |    ent_coef        | 0.355    |
# |    ent_coef_loss   | -0.517   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4348     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -791     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 103      |
# |    time_elapsed    | 92       |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | 72.2     |
# |    critic_loss     | 0.991    |
# |    ent_coef        | 0.324    |
# |    ent_coef_loss   | -0.455   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4748     |
# ---------------------------------

# %% [markdown]
# ## Dict Observations

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.envs import SimpleMultiObsEnv


# Stable Baselines provides SimpleMultiObsEnv as an example environment with Dict observations
env = SimpleMultiObsEnv(random_start=False)

model = PPO("MultiInputPolicy", env, verbose=1)
model.learn(total_timesteps=100_000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.5     |
# |    ep_rew_mean     | -4.59    |
# | time/              |          |
# |    fps             | 853      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.4        |
# |    ep_rew_mean          | -3.37       |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.018651037 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0737      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.276       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 0.562       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.3        |
# |    ep_rew_mean          | -1.54       |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015865494 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.437       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 0.758       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.8        |
# |    ep_rew_mean          | -0.583      |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.019609397 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.253       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0453     |
# |    value_loss           | 0.702       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.8        |
# |    ep_rew_mean          | -0.283      |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 5           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017700858 |
# |    clip_fraction        | 0.503       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.186       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0502     |
# |    value_loss           | 0.454       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.2        |
# |    ep_rew_mean          | 0.075       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 6           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.018461006 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0202      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0494     |
# |    value_loss           | 0.197       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.5         |
# |    ep_rew_mean          | 0.25        |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 7           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.021720313 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.873      |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00275    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0521     |
# |    value_loss           | 0.0905      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.52        |
# |    ep_rew_mean          | 0.348       |
# | time/                   |             |
# |    fps                  | 232         |
# |    iterations           | 8           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.034930028 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0343     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0462     |
# |    value_loss           | 0.0378      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.67        |
# |    ep_rew_mean          | 0.433       |
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 9           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.054169748 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.447      |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0503     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0433     |
# |    value_loss           | 0.0152      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.1        |
# |    ep_rew_mean          | 0.49       |
# | time/                   |            |
# |    fps                  | 226        |
# |    iterations           | 10         |
# |    time_elapsed         | 90         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.09777932 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.257     |
# |    explained_variance   | 0.821      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0215    |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0285    |
# |    value_loss           | 0.00846    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.81        |
# |    ep_rew_mean          | 0.419       |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 11          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.016890002 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.21       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00494    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.000473    |
# |    value_loss           | 0.00138     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.18       |
# |    ep_rew_mean          | 0.482      |
# | time/                   |            |
# |    fps                  | 223        |
# |    iterations           | 12         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.11611434 |
# |    clip_fraction        | 0.295      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.222     |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0477    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0359    |
# |    value_loss           | 0.00539    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.06        |
# |    ep_rew_mean          | 0.494       |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 13          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.028098661 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.15       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0421     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0281     |
# |    value_loss           | 0.00136     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.03        |
# |    ep_rew_mean          | 0.497       |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 14          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.025176968 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0947     |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.046      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.000236    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.01        |
# |    ep_rew_mean          | 0.499       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 15          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009328637 |
# |    clip_fraction        | 0.0161      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0361     |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00204    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00412    |
# |    value_loss           | 5.34e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6           |
# |    ep_rew_mean          | 0.5         |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 16          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.035707507 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.101      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000391    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.0169      |
# |    value_loss           | 2.54e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6          |
# |    ep_rew_mean          | 0.5        |
# | time/                   |            |
# |    fps                  | 219        |
# |    iterations           | 17         |
# |    time_elapsed         | 158        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.12328372 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.104     |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.183      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.0552     |
# |    value_loss           | 6.23e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.07        |
# |    ep_rew_mean          | 0.493       |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 18          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016271405 |
# |    clip_fraction        | 0.0668      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0953     |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0169     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0306      |
# |    value_loss           | 0.00017     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.02         |
# |    ep_rew_mean          | 0.498        |
# | time/                   |              |
# |    fps                  | 219          |
# |    iterations           | 19           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0048511736 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0862      |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0145      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00825     |
# |    value_loss           | 0.000783     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 25.2      |
# |    ep_rew_mean          | -1.62     |
# | time/                   |           |
# |    fps                  | 219       |
# |    iterations           | 20        |
# |    time_elapsed         | 186       |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 1.4036837 |
# |    clip_fraction        | 0.0586    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.074    |
# |    explained_variance   | 0.997     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0131   |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -0.00108  |
# |    value_loss           | 0.000249  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.3        |
# |    ep_rew_mean          | -3.73       |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 21          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.042206608 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.16       |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0403      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00108    |
# |    value_loss           | 0.189       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.3       |
# |    ep_rew_mean          | -1.9       |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 22         |
# |    time_elapsed         | 205        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.17145123 |
# |    clip_fraction        | 0.0966     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.265     |
# |    explained_variance   | 0.151      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0645     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00277   |
# |    value_loss           | 0.256      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.5       |
# |    ep_rew_mean          | -0.547     |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 23         |
# |    time_elapsed         | 215        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02915553 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.419     |
# |    explained_variance   | 0.294      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.491      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0148    |
# |    value_loss           | 1.07       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 33.3      |
# |    ep_rew_mean          | -2.45     |
# | time/                   |           |
# |    fps                  | 218       |
# |    iterations           | 24        |
# |    time_elapsed         | 224       |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.9676976 |
# |    clip_fraction        | 0.25      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.461    |
# |    explained_variance   | 0.409     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.097     |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.0356   |
# |    value_loss           | 0.371     |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49.3         |
# |    ep_rew_mean          | -4.26        |
# | time/                   |              |
# |    fps                  | 218          |
# |    iterations           | 25           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0016050965 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0975      |
# |    explained_variance   | -0.155       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.17         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.00306      |
# |    value_loss           | 0.212        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 66.5         |
# |    ep_rew_mean          | -6.2         |
# | time/                   |              |
# |    fps                  | 218          |
# |    iterations           | 26           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0070443535 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.077       |
# |    explained_variance   | 0.306        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0373       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 1.54e-05     |
# |    value_loss           | 0.197        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81.5         |
# |    ep_rew_mean          | -7.89        |
# | time/                   |              |
# |    fps                  | 218          |
# |    iterations           | 27           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0041716313 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0696      |
# |    explained_variance   | 0.613        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0219       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 0.147        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.7        |
# |    ep_rew_mean          | -7.35       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 28          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.005540125 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0874     |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0479      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00551    |
# |    value_loss           | 0.176       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 17.2       |
# |    ep_rew_mean          | -0.623     |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 29         |
# |    time_elapsed         | 271        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.09925322 |
# |    clip_fraction        | 0.364      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.458     |
# |    explained_variance   | 0.919      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.134      |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0342    |
# |    value_loss           | 0.173      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.8        |
# |    ep_rew_mean          | -0.184      |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 30          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.035813045 |
# |    clip_fraction        | 0.343       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | -1.94       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.106       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0363     |
# |    value_loss           | 0.63        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.41       |
# |    ep_rew_mean          | 0.159      |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 31         |
# |    time_elapsed         | 290        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.03661176 |
# |    clip_fraction        | 0.49       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.575     |
# |    explained_variance   | 0.251      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0315     |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0479    |
# |    value_loss           | 0.18       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.39        |
# |    ep_rew_mean          | 0.261       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 32          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.019251205 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.526      |
# |    explained_variance   | 0.465       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.016      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0475     |
# |    value_loss           | 0.0509      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.65       |
# |    ep_rew_mean          | 0.335      |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 33         |
# |    time_elapsed         | 308        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.02294166 |
# |    clip_fraction        | 0.482      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.451     |
# |    explained_variance   | 0.664      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0236    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0615    |
# |    value_loss           | 0.0325     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.98        |
# |    ep_rew_mean          | 0.402       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 34          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.023545261 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.36       |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0502     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0543     |
# |    value_loss           | 0.0191      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.64       |
# |    ep_rew_mean          | 0.436      |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 35         |
# |    time_elapsed         | 327        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.02227071 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.267     |
# |    explained_variance   | 0.797      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.05      |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0482    |
# |    value_loss           | 0.0102     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.24        |
# |    ep_rew_mean          | 0.476       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 36          |
# |    time_elapsed         | 337         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.047102857 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.17       |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0601     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0405     |
# |    value_loss           | 0.00524     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.22        |
# |    ep_rew_mean          | 0.478       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 37          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004597257 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.128      |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00713    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 0.00214     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.01       |
# |    ep_rew_mean          | 0.499      |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 38         |
# |    time_elapsed         | 355        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.15603222 |
# |    clip_fraction        | 0.0397     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0384    |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0245    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0226    |
# |    value_loss           | 0.00222    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.6       |
# |    ep_rew_mean          | -0.26      |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 39         |
# |    time_elapsed         | 365        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.11450238 |
# |    clip_fraction        | 0.208      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.221     |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0571    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0249    |
# |    value_loss           | 9.67e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.57       |
# |    ep_rew_mean          | 0.343      |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 40         |
# |    time_elapsed         | 374        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.14632544 |
# |    clip_fraction        | 0.552      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.461     |
# |    explained_variance   | 0.225      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0461    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0857    |
# |    value_loss           | 0.161      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.92       |
# |    ep_rew_mean          | 0.408      |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 41         |
# |    time_elapsed         | 384        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.07207234 |
# |    clip_fraction        | 0.392      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.315     |
# |    explained_variance   | 0.396      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0475    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0522    |
# |    value_loss           | 0.0529     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.69        |
# |    ep_rew_mean          | 0.431       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 42          |
# |    time_elapsed         | 393         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.022851422 |
# |    clip_fraction        | 0.338       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.189      |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0355     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0502     |
# |    value_loss           | 0.0144      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.1        |
# |    ep_rew_mean          | 0.49       |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 43         |
# |    time_elapsed         | 402        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.29474822 |
# |    clip_fraction        | 0.253      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0416    |
# |    explained_variance   | 0.83       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0355    |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0495    |
# |    value_loss           | 0.00807    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.02        |
# |    ep_rew_mean          | 0.498       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 44          |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.002966823 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0287     |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0173     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0018     |
# |    value_loss           | 0.00128     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 20        |
# |    ep_rew_mean          | -0.898    |
# | time/                   |           |
# |    fps                  | 218       |
# |    iterations           | 45        |
# |    time_elapsed         | 421       |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.3988942 |
# |    clip_fraction        | 0.248     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.132    |
# |    explained_variance   | 0.984     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0719   |
# |    n_updates            | 440       |
# |    policy_gradient_loss | 0.537     |
# |    value_loss           | 0.000436  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.08       |
# |    ep_rew_mean          | 0.192      |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 46         |
# |    time_elapsed         | 430        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.08811721 |
# |    clip_fraction        | 0.409      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.439     |
# |    explained_variance   | 0.141      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0305     |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0484    |
# |    value_loss           | 0.211      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.66       |
# |    ep_rew_mean          | 0.334      |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 47         |
# |    time_elapsed         | 440        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.02171062 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.327     |
# |    explained_variance   | 0.369      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0249     |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0303    |
# |    value_loss           | 0.113      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.26        |
# |    ep_rew_mean          | 0.374       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 48          |
# |    time_elapsed         | 449         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009975312 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.266      |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.021      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0407     |
# |    value_loss           | 0.033       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.65        |
# |    ep_rew_mean          | 0.435       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 49          |
# |    time_elapsed         | 459         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.009402221 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.21       |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0317     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0475     |
# |    value_loss           | 0.0155      |
# -----------------------------------------

# %%
import os

import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import TD3
from stable_baselines3.common import results_plotter
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy, plot_results
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback


class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq:
    :param log_dir: Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: Verbosity level: 0 for no output, 1 for info messages, 2 for debug messages
    """
    def __init__(self, check_freq: int, log_dir: str, verbose: int = 1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

          # Retrieve training reward
          x, y = ts2xy(load_results(self.log_dir), "timesteps")
          if len(x) > 0:
              # Mean training reward over the last 100 episodes
              mean_reward = np.mean(y[-100:])
              if self.verbose >= 1:
                print(f"Num timesteps: {self.num_timesteps}")
                print(f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}")

              # New best model, you could save the agent here
              if mean_reward > self.best_mean_reward:
                  self.best_mean_reward = mean_reward
                  # Example for saving best model
                  if self.verbose >= 1:
                    print(f"Saving new best model to {self.save_path}")
                  self.model.save(self.save_path)

        return True

# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = gym.make("LunarLanderContinuous-v2")
env = Monitor(env, log_dir)

# Add some action noise for exploration
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
# Because we use parameter noise, we should use a MlpPolicy with layer normalization
model = TD3("MlpPolicy", env, action_noise=action_noise, verbose=0)
# Create the callback: check every 1000 steps
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)
# Train the agent
timesteps = 1e5
model.learn(total_timesteps=int(timesteps), callback=callback)

plot_results([log_dir], timesteps, results_plotter.X_TIMESTEPS, "TD3 LunarLander")
plt.show()
# Out:
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -261.00
# Saving new best model to tmp/best_model
# Num timesteps: 2000
# Best mean reward: -261.00 - Last mean reward per episode: -232.77
# Saving new best model to tmp/best_model
# Num timesteps: 3000
# Best mean reward: -232.77 - Last mean reward per episode: -209.66
# Saving new best model to tmp/best_model
# Num timesteps: 4000
# Best mean reward: -209.66 - Last mean reward per episode: -201.19
# Saving new best model to tmp/best_model
# Num timesteps: 5000
# Best mean reward: -201.19 - Last mean reward per episode: -209.87
# Num timesteps: 6000
# Best mean reward: -201.19 - Last mean reward per episode: -204.19
# Num timesteps: 7000
# Best mean reward: -201.19 - Last mean reward per episode: -194.29
# Saving new best model to tmp/best_model
# Num timesteps: 8000
# Best mean reward: -194.29 - Last mean reward per episode: -194.74
# Num timesteps: 9000
# Best mean reward: -194.29 - Last mean reward per episode: -171.71
# Saving new best model to tmp/best_model
# Num timesteps: 10000
# Best mean reward: -171.71 - Last mean reward per episode: -164.29
# Saving new best model to tmp/best_model
# Num timesteps: 11000
# Best mean reward: -164.29 - Last mean reward per episode: -161.81
# Saving new best model to tmp/best_model
# Num timesteps: 12000
# Best mean reward: -161.81 - Last mean reward per episode: -166.05
# Num timesteps: 13000
# Best mean reward: -161.81 - Last mean reward per episode: -162.54
# Num timesteps: 14000
# Best mean reward: -161.81 - Last mean reward per episode: -166.71
# Num timesteps: 15000
# Best mean reward: -161.81 - Last mean reward per episode: -164.53
# Num timesteps: 16000
# Best mean reward: -161.81 - Last mean reward per episode: -162.51
# Num timesteps: 17000
# Best mean reward: -161.81 - Last mean reward per episode: -153.56
# Saving new best model to tmp/best_model
# Num timesteps: 18000
# Best mean reward: -153.56 - Last mean reward per episode: -152.79
# Saving new best model to tmp/best_model
# Num timesteps: 19000
# Best mean reward: -152.79 - Last mean reward per episode: -148.58
# Saving new best model to tmp/best_model
# Num timesteps: 20000
# Best mean reward: -148.58 - Last mean reward per episode: -132.01
# Saving new best model to tmp/best_model
# Num timesteps: 21000
# Best mean reward: -132.01 - Last mean reward per episode: -128.35
# Saving new best model to tmp/best_model
# Num timesteps: 22000
# Best mean reward: -128.35 - Last mean reward per episode: -124.73
# Saving new best model to tmp/best_model
# Num timesteps: 23000
# Best mean reward: -124.73 - Last mean reward per episode: -122.09
# Saving new best model to tmp/best_model
# Num timesteps: 24000
# Best mean reward: -122.09 - Last mean reward per episode: -124.00
# Num timesteps: 25000
# Best mean reward: -122.09 - Last mean reward per episode: -127.60
# Num timesteps: 26000
# Best mean reward: -122.09 - Last mean reward per episode: -134.27
# Num timesteps: 27000
# Best mean reward: -122.09 - Last mean reward per episode: -136.01
# Num timesteps: 28000
# Best mean reward: -122.09 - Last mean reward per episode: -136.09
# Num timesteps: 29000
# Best mean reward: -122.09 - Last mean reward per episode: -129.50
# Num timesteps: 30000
# Best mean reward: -122.09 - Last mean reward per episode: -124.73
# Num timesteps: 31000
# Best mean reward: -122.09 - Last mean reward per episode: -121.88
# Saving new best model to tmp/best_model
# Num timesteps: 32000
# Best mean reward: -121.88 - Last mean reward per episode: -121.79
# Saving new best model to tmp/best_model
# Num timesteps: 33000
# Best mean reward: -121.79 - Last mean reward per episode: -119.11
# Saving new best model to tmp/best_model
# Num timesteps: 34000
# Best mean reward: -119.11 - Last mean reward per episode: -118.31
# Saving new best model to tmp/best_model
# Num timesteps: 35000
# Best mean reward: -118.31 - Last mean reward per episode: -116.61
# Saving new best model to tmp/best_model
# Num timesteps: 36000
# Best mean reward: -116.61 - Last mean reward per episode: -113.80
# Saving new best model to tmp/best_model
# Num timesteps: 37000
# Best mean reward: -113.80 - Last mean reward per episode: -111.43
# Saving new best model to tmp/best_model
# Num timesteps: 38000
# Best mean reward: -111.43 - Last mean reward per episode: -110.02
# Saving new best model to tmp/best_model
# Num timesteps: 39000
# Best mean reward: -110.02 - Last mean reward per episode: -106.98
# Saving new best model to tmp/best_model
# Num timesteps: 40000
# Best mean reward: -106.98 - Last mean reward per episode: -105.89
# Saving new best model to tmp/best_model
# Num timesteps: 41000
# Best mean reward: -105.89 - Last mean reward per episode: -102.73
# Saving new best model to tmp/best_model
# Num timesteps: 42000
# Best mean reward: -102.73 - Last mean reward per episode: -99.66
# Saving new best model to tmp/best_model
# Num timesteps: 43000
# Best mean reward: -99.66 - Last mean reward per episode: -100.13
# Num timesteps: 44000
# Best mean reward: -99.66 - Last mean reward per episode: -98.94
# Saving new best model to tmp/best_model
# Num timesteps: 45000
# Best mean reward: -98.94 - Last mean reward per episode: -100.36
# Num timesteps: 46000
# Best mean reward: -98.94 - Last mean reward per episode: -96.34
# Saving new best model to tmp/best_model
# Num timesteps: 47000
# Best mean reward: -96.34 - Last mean reward per episode: -95.96
# Saving new best model to tmp/best_model
# Num timesteps: 48000
# Best mean reward: -95.96 - Last mean reward per episode: -94.50
# Saving new best model to tmp/best_model
# Num timesteps: 49000
# Best mean reward: -94.50 - Last mean reward per episode: -96.06
# Num timesteps: 50000
# Best mean reward: -94.50 - Last mean reward per episode: -94.78
# Num timesteps: 51000
# Best mean reward: -94.50 - Last mean reward per episode: -91.76
# Saving new best model to tmp/best_model
# Num timesteps: 52000
# Best mean reward: -91.76 - Last mean reward per episode: -89.26
# Saving new best model to tmp/best_model
# Num timesteps: 53000
# Best mean reward: -89.26 - Last mean reward per episode: -88.50
# Saving new best model to tmp/best_model
# Num timesteps: 54000
# Best mean reward: -88.50 - Last mean reward per episode: -83.28
# Saving new best model to tmp/best_model
# Num timesteps: 55000
# Best mean reward: -83.28 - Last mean reward per episode: -89.11
# Num timesteps: 56000
# Best mean reward: -83.28 - Last mean reward per episode: -82.74
# Saving new best model to tmp/best_model
# Num timesteps: 57000
# Best mean reward: -82.74 - Last mean reward per episode: -83.72
# Num timesteps: 58000
# Best mean reward: -82.74 - Last mean reward per episode: -83.18
# Num timesteps: 59000
# Best mean reward: -82.74 - Last mean reward per episode: -83.00
# Num timesteps: 60000
# Best mean reward: -82.74 - Last mean reward per episode: -74.64
# Saving new best model to tmp/best_model
# Num timesteps: 61000
# Best mean reward: -74.64 - Last mean reward per episode: -71.73
# Saving new best model to tmp/best_model
# Num timesteps: 62000
# Best mean reward: -71.73 - Last mean reward per episode: -75.21
# Num timesteps: 63000
# Best mean reward: -71.73 - Last mean reward per episode: -75.38
# Num timesteps: 64000
# Best mean reward: -71.73 - Last mean reward per episode: -79.06
# Num timesteps: 65000
# Best mean reward: -71.73 - Last mean reward per episode: -79.62
# Num timesteps: 66000
# Best mean reward: -71.73 - Last mean reward per episode: -77.70
# Num timesteps: 67000
# Best mean reward: -71.73 - Last mean reward per episode: -78.66
# Num timesteps: 68000
# Best mean reward: -71.73 - Last mean reward per episode: -78.66
# Num timesteps: 69000
# Best mean reward: -71.73 - Last mean reward per episode: -78.63
# Num timesteps: 70000
# Best mean reward: -71.73 - Last mean reward per episode: -79.94
# Num timesteps: 71000
# Best mean reward: -71.73 - Last mean reward per episode: -81.07
# Num timesteps: 72000
# Best mean reward: -71.73 - Last mean reward per episode: -78.36
# Num timesteps: 73000
# Best mean reward: -71.73 - Last mean reward per episode: -75.89
# Num timesteps: 74000
# Best mean reward: -71.73 - Last mean reward per episode: -75.87
# Num timesteps: 75000
# Best mean reward: -71.73 - Last mean reward per episode: -71.00
# Saving new best model to tmp/best_model
# Num timesteps: 76000
# Best mean reward: -71.00 - Last mean reward per episode: -68.97
# Saving new best model to tmp/best_model
# Num timesteps: 77000
# Best mean reward: -68.97 - Last mean reward per episode: -66.51
# Saving new best model to tmp/best_model
# Num timesteps: 78000
# Best mean reward: -66.51 - Last mean reward per episode: -62.74
# Saving new best model to tmp/best_model
# Num timesteps: 79000
# Best mean reward: -62.74 - Last mean reward per episode: -61.42
# Saving new best model to tmp/best_model
# Num timesteps: 80000
# Best mean reward: -61.42 - Last mean reward per episode: -58.11
# Saving new best model to tmp/best_model
# Num timesteps: 81000
# Best mean reward: -58.11 - Last mean reward per episode: -56.78
# Saving new best model to tmp/best_model
# Num timesteps: 82000
# Best mean reward: -56.78 - Last mean reward per episode: -56.48
# Saving new best model to tmp/best_model
# Num timesteps: 83000
# Best mean reward: -56.48 - Last mean reward per episode: -55.97
# Saving new best model to tmp/best_model
# Num timesteps: 84000
# Best mean reward: -55.97 - Last mean reward per episode: -56.29
# Num timesteps: 85000
# Best mean reward: -55.97 - Last mean reward per episode: -54.18
# Saving new best model to tmp/best_model
# Num timesteps: 86000
# Best mean reward: -54.18 - Last mean reward per episode: -53.35
# Saving new best model to tmp/best_model
# Num timesteps: 87000
# Best mean reward: -53.35 - Last mean reward per episode: -51.47
# Saving new best model to tmp/best_model
# Num timesteps: 88000
# Best mean reward: -51.47 - Last mean reward per episode: -53.53
# Num timesteps: 89000
# Best mean reward: -51.47 - Last mean reward per episode: -53.43
# Num timesteps: 90000
# Best mean reward: -51.47 - Last mean reward per episode: -53.21
# Num timesteps: 91000
# Best mean reward: -51.47 - Last mean reward per episode: -52.34
# Num timesteps: 92000
# Best mean reward: -51.47 - Last mean reward per episode: -46.43
# Saving new best model to tmp/best_model
# Num timesteps: 93000
# Best mean reward: -46.43 - Last mean reward per episode: -45.87
# Saving new best model to tmp/best_model
# Num timesteps: 94000
# Best mean reward: -45.87 - Last mean reward per episode: -44.05
# Saving new best model to tmp/best_model
# Num timesteps: 95000
# Best mean reward: -44.05 - Last mean reward per episode: -38.56
# Saving new best model to tmp/best_model
# Num timesteps: 96000
# Best mean reward: -38.56 - Last mean reward per episode: -37.71
# Saving new best model to tmp/best_model
# Num timesteps: 97000
# Best mean reward: -37.71 - Last mean reward per episode: -37.02
# Saving new best model to tmp/best_model
# Num timesteps: 98000
# Best mean reward: -37.02 - Last mean reward per episode: -36.25
# Saving new best model to tmp/best_model
# Num timesteps: 99000
# Best mean reward: -36.25 - Last mean reward per episode: -36.97
# Num timesteps: 100000
# Best mean reward: -36.25 - Last mean reward per episode: -32.67
# Saving new best model to tmp/best_model

# %% [markdown]
# ## Atari Games

# %%
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3 import A2C

# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
vec_env = make_atari_env("PongNoFrameskip-v4", n_envs=4, seed=0)
# Frame-stacking with 4 frames
vec_env = VecFrameStack(vec_env, n_stack=4)

model = A2C("CnnPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25_000)

obs = vec_env.reset()
while True:
    action, _states = model.predict(obs, deterministic=False)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ------------------------------------
# | time/                 |          |
# |    fps                | 290      |
# |    iterations         | 100      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.19    |
# |    explained_variance | 0.0235   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.0696   |
# |    value_loss         | 0.00251  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.29e+03  |
# |    ep_rew_mean        | -20.7     |
# | time/                 |           |
# |    fps                | 298       |
# |    iterations         | 200       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -1.74     |
# |    explained_variance | -0.000658 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -0.752    |
# |    value_loss         | 0.366     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.54e+03 |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 300      |
# |    iterations         | 300      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.65    |
# |    explained_variance | 0.000184 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.221   |
# |    value_loss         | 0.177    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.34e+03 |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 301      |
# |    iterations         | 400      |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.74    |
# |    explained_variance | -0.00109 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.206   |
# |    value_loss         | 0.136    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.31e+03 |
# |    ep_rew_mean        | -20.7    |
# | time/                 |          |
# |    fps                | 303      |
# |    iterations         | 500      |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.7     |
# |    explained_variance | -0.0102  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.0954   |
# |    value_loss         | 0.00349  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.34e+03 |
# |    ep_rew_mean        | -20.7    |
# | time/                 |          |
# |    fps                | 303      |
# |    iterations         | 600      |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.75    |
# |    explained_variance | -0.00109 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.193   |
# |    value_loss         | 0.133    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.27e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 303      |
# |    iterations         | 700      |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | -0.0252  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.0517   |
# |    value_loss         | 0.000992 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.28e+03 |
# |    ep_rew_mean        | -20.7    |
# | time/                 |          |
# |    fps                | 303      |
# |    iterations         | 800      |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.0276   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0702   |
# |    value_loss         | 0.00185  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.32e+03 |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 303      |
# |    iterations         | 900      |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | -0.00017 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0359  |
# |    value_loss         | 0.0456   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.35e+03 |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 305      |
# |    iterations         | 1000     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.00101  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.334    |
# |    value_loss         | 0.162    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.37e+03 |
# |    ep_rew_mean        | -20.7    |
# | time/                 |          |
# |    fps                | 305      |
# |    iterations         | 1100     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.00108  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.226   |
# |    value_loss         | 0.139    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.43e+03 |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 305      |
# |    iterations         | 1200     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | -2.56    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.0292   |
# |    value_loss         | 0.000749 |
# ------------------------------------
# /Users/gaohaitao/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/gaohaitao/robotics-tutorial/atari_rl/introduce_sb3.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell:/Users/gaohaitao/robotics-tutorial/atari_rl/introduce_sb3.ipynb#X16sZmlsZQ%3D%3D?line=16'>17</a> action, _states = model.predict(obs, deterministic=False)
#      <a href='vscode-notebook-cell:/Users/gaohaitao/robotics-tutorial/atari_rl/introduce_sb3.ipynb#X16sZmlsZQ%3D%3D?line=17'>18</a> obs, rewards, dones, info = vec_env.step(action)
# ---> <a href='vscode-notebook-cell:/Users/gaohaitao/robotics-tutorial/atari_rl/introduce_sb3.ipynb#X16sZmlsZQ%3D%3D?line=18'>19</a> vec_env.render("human")
#
# File ~/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:361, in VecEnvWrapper.render(self, mode)
#     360 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
# --> 361     return self.venv.render(mode=mode)
#
# File ~/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:101, in DummyVecEnv.render(self, mode)
#      94 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
#      95     """
#      96     Gym environment rendering. If there are multiple environments then
#      97     they are tiled together in one image via ``BaseVecEnv.render()``.
#      98
#      99     :param mode: The rendering type.
#     100     """
# --> 101     return super().render(mode=mode)
#
# File ~/opt/anaconda3/envs/robotics/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:255, in VecEnv.render(self, mode)
#     252     import cv2  # pytype:disable=import-error
#     254     cv2.imshow("vecenv", bigimg[:, :, ::-1])
# --> 255     cv2.waitKey(1)
#     256 else:
#     257     return bigimg
#
# KeyboardInterrupt:

# %%
import gymnasium as gym
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv

env_id = "CartPole-v1"
video_folder = "logs/videos/"
video_length = 100

vec_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])

obs = vec_env.reset()

# Record the video starting at the first step
vec_env = VecVideoRecorder(vec_env, video_folder,
                       record_video_trigger=lambda x: x == 0, video_length=video_length,
                       name_prefix=f"random-agent-{env_id}")

vec_env.reset()
for _ in range(video_length + 1):
  action = [vec_env.action_space.sample()]
  obs, _, _, _ = vec_env.step(action)
# Save the video
vec_env.close()
# Out:
# Saving video to /Users/gaohaitao/robotics-tutorial/atari_rl/logs/videos/random-agent-CartPole-v1-step-0-to-step-100.mp4
# Moviepy - Building video /Users/gaohaitao/robotics-tutorial/atari_rl/logs/videos/random-agent-CartPole-v1-step-0-to-step-100.mp4.
# Moviepy - Writing video /Users/gaohaitao/robotics-tutorial/atari_rl/logs/videos/random-agent-CartPole-v1-step-0-to-step-100.mp4
# Moviepy - Done !
# Moviepy - video ready /Users/gaohaitao/robotics-tutorial/atari_rl/logs/videos/random-agent-CartPole-v1-step-0-to-step-100.mp4

# %%
import imageio
import numpy as np

from stable_baselines3 import A2C

model = A2C("MlpPolicy", "LunarLander-v2").learn(100_000)

images = []
obs = model.env.reset()
img = model.env.render(mode="rgb_array")
for i in range(350):
    images.append(img)
    action, _ = model.predict(obs)
    obs, _, _ ,_ = model.env.step(action)
    img = model.env.render(mode="rgb_array")

imageio.mimsave("lander_a2c.gif", [np.array(img) for i, img in enumerate(images) if i%2 == 0], duration=29)
